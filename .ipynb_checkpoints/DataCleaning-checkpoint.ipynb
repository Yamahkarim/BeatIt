# %%
#Dependencies
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Data Cleaning

# %%
#load CSV 
data_to_load = os.path.join('data', 'beatsdataset.csv')
data = pd.read_csv(data_to_load) 
data.head()
# Out:
#    Unnamed: 0    1-ZCRm  2-Energym  3-EnergyEntropym  4-SpectralCentroidm  \
# 0           0  0.136440   0.088861          3.201201             0.262825
# 1           1  0.117039   0.108389          3.194001             0.247657
# 2           2  0.085308   0.128525          3.123837             0.217205
# 3           3  0.103050   0.167042          3.150830             0.233593
# 4           4  0.151730   0.148405          3.194498             0.293730
#
#    5-SpectralSpreadm  6-SpectralEntropym  7-SpectralFluxm  8-SpectralRolloffm  \
# 0           0.249212            1.114423         0.007003            0.256682
# 1           0.250288            1.065668         0.005387            0.199821
# 2           0.228652            0.789647         0.008247            0.156822
# 3           0.245032            0.967082         0.006571            0.168083
# 4           0.267231            1.353005         0.003872            0.292055
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 73 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2300 non-null   int64
#  1   1-ZCRm                  2300 non-null   float64
#  2   2-Energym               2300 non-null   float64
#  3   3-EnergyEntropym        2300 non-null   float64
#  4   4-SpectralCentroidm     2300 non-null   float64
#  5   5-SpectralSpreadm       2300 non-null   float64
#  6   6-SpectralEntropym      2300 non-null   float64
#  7   7-SpectralFluxm         2300 non-null   float64
#  8   8-SpectralRolloffm      2300 non-null   float64
#  9   9-MFCCs1m               2300 non-null   float64
#  10  10-MFCCs2m              2300 non-null   float64
#  11  11-MFCCs3m              2300 non-null   float64
#  12  12-MFCCs4m              2300 non-null   float64
#  13  13-MFCCs5m              2300 non-null   float64
# ...

# %%
#Extract Classes for the names of Sub Genres
data['class'].unique()
# Out:
# array(['BigRoom', 'Breaks', 'Dance', 'DeepHouse', 'DrumAndBass',
#        'Dubstep', 'ElectroHouse', 'ElectronicaDowntempo', 'FunkRAndB',
#        'FutureHouse', 'GlitchHop', 'HardcoreHardTechno', 'HardDance',
#        'HipHop', 'House', 'IndieDanceNuDisco', 'Minimal',
#        'ProgressiveHouse', 'PsyTrance', 'ReggaeDub', 'TechHouse',
#        'Techno', 'Trance'], dtype=object)

# %%
#Remove unneccarry columns from dataframe 
finalDF = data[['1-ZCRm','4-SpectralCentroidm', '6-SpectralEntropym', '7-SpectralFluxm','8-SpectralRolloffm', '71-BPMessentia','class']]
finalDF.head()
# Out:
#      1-ZCRm  4-SpectralCentroidm  6-SpectralEntropym  7-SpectralFluxm  \
# 0  0.136440             0.262825            1.114423         0.007003
# 1  0.117039             0.247657            1.065668         0.005387
# 2  0.085308             0.217205            0.789647         0.008247
# 3  0.103050             0.233593            0.967082         0.006571
# 4  0.151730             0.293730            1.353005         0.003872
#
#    8-SpectralRolloffm  71-BPMessentia    class
# 0            0.256682             128  BigRoom
# 1            0.199821             126  BigRoom
# 2            0.156822             129  BigRoom
# 3            0.168083             129  BigRoom
# 4            0.292055             129  BigRoom

# %%
#create a new CSV with only the data that we need
finalDF.to_csv(r'/Users/yamah/Documents/Work/PortfolioRepo/BeatIt/data/cleandata2020')

# %% [markdown]
# # Exploratory analysis With Panads Profiling

# %%
#import package
from pandas_profiling import ProfileReport

# %%
#Generate Report for Notebook
ProfileReport(finalDF)
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:4298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ...

# %%
#export Report
prof = ProfileReport(finalDF)
prof.to_file(output_file='ReportOutput.html')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:4298: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# ...
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# ...
